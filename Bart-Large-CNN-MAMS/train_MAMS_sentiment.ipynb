# %%
#!pip install torch

# %%
#!pip install matplotlib

# %%
#!pip install pandas

# %%
from seq2seq_model_M import Seq2SeqModel
import pandas as pd
import torch

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
if torch.cuda.is_available():
    print(f"CUDA devices available: {torch.cuda.device_count()}")
    print(f"Current CUDA device index: {torch.cuda.current_device()}")
    print(f"Current CUDA device name: {torch.cuda.get_device_name(torch.cuda.current_device())}")
else:
    print("CUDA is not available. Switch to CPU mode or check your CUDA installation.")

device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
device
# Out:
# CUDA devices available: 1
# Current CUDA device index: 0
# Current CUDA device name: NVIDIA RTX A6000
# device(type='cuda', index=1)

# %%
# logging.basicConfig(level=logging.INFO)
# transformers_logger = logging.getLogger("transformers")
# transformers_logger.setLevel(logging.WARNING)
torch.cuda.empty_cache()

# %%
# !ls crossvalid/set1
# Out:
# combined.txt  train1_AIgen_Trans.txt  train1_og_backtrans_AIgen.txt
# test1.txt     train1_aug.txt

# %%
with open("crossvalid/set5/train5_aug.txt", "r",encoding='utf-8') as f:
    file = f.readlines()
train_data = []
for line in file:
    # print(line)
    x, y = line.split("\001")[0], line.strip().split("\001")[1]
    train_data.append([x, y])
    #else:
    #    print(f"Issue with line: {line.strip()}")
# train_data = [
#     ["one", "1"],
#     ["two", "2"],
# ]

train_df = pd.DataFrame(train_data, columns=["input_text", "target_text"])
#print(train_df["target_text"])
# steps = [1, 2, 3, 4, 6]
# learing_rates = [4e-5, 2e-5, 1e-5, 3e-5]
steps = [1]
learing_rates = [4e-5]



best_accuracy = 0
for lr in learing_rates:
    for step in steps:
        model_args = {
            "reprocess_input_data": True,
            "overwrite_output_dir": True,
            "max_seq_length": 50,
            "train_batch_size": 16,
            "num_train_epochs": 5,
            "save_eval_checkpoints": True,
            "save_model_every_epoch": True,
            "evaluate_during_training": False,
            "evaluate_generated_text": False,
            "evaluate_during_training_verbose": True,
            "use_multiprocessing": False,
            "max_length": 150,
            "manual_seed": 42,
            "gradient_accumulation_steps": step,
            "learning_rate":  lr,
            "save_steps": 99999999999999,
        }

        torch.cuda.empty_cache()

        # Initialize model
        model = Seq2SeqModel(
            encoder_decoder_type="bart",
            encoder_decoder_name="outputs/Augment Full/bart_cnn_k4",
            # encoder_decoder_name="facebook/bart-large-cnn",
            args=model_args,
        )

        #print(model)

        # Train the model
        best_accuracy = model.train_model(train_df, best_accuracy)
# Out:
# cuda is used
#   0%|          | 0/3212 [00:00<?, ?it/s]
# Epoch:   0%|          | 0/5 [00:00<?, ?it/s]
# Running Epoch 0 of 5:   0%|          | 0/201 [00:00<?, ?it/s]
# Input Sentence: Deciding to host onsite classes and her only appearing in online meetings is one of the worst experiences I have ever felt, sure, [instructor] may have health issues but could have hosted online classes. To add an insult to
# Predicted Sentence: The sentiment polarity of re is neutral.]]]]] pol]]]]] explains language explains]]] explains explains]] negative] explains negative topicarity organization] organization explains language explains explains organization
#
# Input Sentence: Please let students have attendance checks while some phones aren't capable to scan from some distance or have another way for attendance
# Predicted Sentence: The sentiment polarity of instructor is neutral.]]]]]]]]] is explains explains language is explains]]] explains topic sentiment explains] sentiment explains explains explains] language negative explains negative negative explains topic
#
# Input Sentence: as the path of teaching
# Predicted Sentence: The sentiment polarity of learning is neutral.] topic]]]]]]] topic]]] is explainsarity sentiment sentiment explains explains topic topic explains sentiment explainsarity. explains explains explains explains explains sentiment organization explains explains
#
# Input Sentence: Add more technology cultural evolution
# Predicted Sentence: The sentiment polarity of organization goal alignment is neutral.]]] explains]]]]]] explains explains explains explains negative explains. negative negative is very] negative negative explains is negative explains negative pol organization is explains
#
# Input Sentence: The due date of homework should be the next date of the assignment.
# Predicted Sentence: The sentiment polarity of re is neutral.]]]] explains]]] negative] explains explains explains explains]] negative] explains explains pol is is explains negativearity organization is explains is very is explains explains
#
# Input Sentence: This class is the least enjoyable class in this semeseter. The weekly assignment in my opinion is not nessecary. This class's assignment is too heavy, and it takes up most of the time I have spent in this semester
# Predicted Sentence: The sentiment polarity of instructor goal alignment is neutral.]] is] is]]] organization explains explains explains]] explains]] organization. negative very explains explains. explains topic explains explainsances
#
# Input Sentence: Want the teacher to pay attention to all students
# Predicted Sentence: The sentiment polarity of instructor and adaptation is neutral.] topic] explains]]] explains] explains explains] explains is explains explains explains sentiment explains explains pol pol negative is sentiment explains organization is pol explains pol explains explains language organization
#
# Input Sentence: The project should not assign the students during the week of exams because we must rest and review the conference. We cannot therefore focus fully on the project.
# Predicted Sentence: The sentiment polarity of instructor goal alignment is neutral.]]]]]] explains]] explains explains]] explains explains is explains explains explains negative explains negative explains explains.arity is sentiment organization.. organization. organization
#
# Input Sentence: Giving assignments every week and group projects almost every week is too excessive, there is too much workload and those assignments are not really helpful for studying the course in my opinion. The group report may be a bit too harsh on minimum pages when there
# Predicted Sentence: The sentiment polarity of motivationusability is neutral.ad]]]]] topic] explains] explains explains.]] pol negative organization negative organization organization explains explains negative explains. negative language. explains organization
#
# Input Sentence: I want the teacher to teach a little slower.
# Predicted Sentence: The sentiment polarity of instructor quality is neutral..]]]]]]]] explains is is is is language] negative explains explains sentiment. explains pol negative explains organization] organization organization explains organization organization. organization explains explains
#
# Input Sentence: I like the comments in real time that [the instructor] gave during the lessons.
# Predicted Sentence: The sentiment polarity of motivation quality is neutral.]]]]]]]]]] language] explains explains explains explains explains sentiment sentiment explains explains negative is. pol is negative language. organization language language organization organization. is
#
# Input Sentence: Reduce homework, give more time to do quiz.
# Predicted Sentence: The sentiment polarity of reusability is neutral.] topic is]]]]]] explains explains explains explains] explains] explains is explains explains explains explains explains explains explains is. explains explains explains pol negative language organization
#
# Input Sentence: Please don't teach too slowly
# Predicted Sentence: The sentiment polarity of re is neutral.]] explains is]]]]] explains explains explains explains explains]]]] explains explains sentiment explains negative negative sentiment organization. sentiment negative negative pol sentiment explains explains language topic explains explains
#
# Input Sentence: I believe that this topic has a lot of advantages, but the workload for students compared to other classes is too much. If it is almost an exam week, we have to submit work after this class. I think tasks should be less with
# Predicted Sentence: The sentiment polarity of content is neutral.] explains explains explains]]]] explains sentiment explains sentiment sentiment] explains explains explains sentiment explains explains explains is pol explains explains explains language explains explains explains explains. sentiment explains]
#
# Input Sentence: [instructor] accent is hard to understand a lesson.
# Predicted Sentence: The sentiment polarity of learningusability is neutral. explains]] explains]] explains] explains explains] explains explains explains] explains explains negative explains negative explains pol explains explains explains negativearity explains organization explains explains explains organization
#
# Input Sentence: Hopes that [the instructor] lists the assignment in [system]. At one point, I forgot the mission.
# Predicted Sentence: The sentiment polarity of instructorusability is neutral.]]]]]]]] sentiment] is explains explains] explains organization is sentiment. explains explains explains very negative negative negative explains negative explains negative
#
#
#
# Input Sentence: After Midterm is not really good with [instructor], his teaching method is difficult to understand, but he accuses the students to use "ears and eyes" to look and listen. He is not easy to approach.
# Predicted Sentence: The sentiment polarity of instructor usability is neutral.] topic explains]]]]]]] explains]]. organization explains sentiment explains explains negative explains] negative explains organization language is language explains organization sentiment is explains
#
# Input Sentence: Please listen to the more students' opinion
# Predicted Sentence: The sentiment polarity of instructor is neutral. explains explains]]]]]]] explains explains explains explains explains is explains] explains] explains] negative topic explains explains sentiment negative explains negative topic explains pol explains language negative explains
#
# Input Sentence: AT is very effective.
# Predicted Sentence: The sentiment polarity of re is neutral.]arity]]]]]]]] sentiment] sentimentances explains] explains] explains explains explains explains explains explains explains explains explains explains negative is explains negative organization organizationarity explains
#
# Input Sentence: I like the teacher very much. I understand. I know about it, but because I am not very practicing so I can't do it.
# Predicted Sentence: The sentiment polarity of learning usability is neutral.us]]]]]]]]] explains explains is explains explains explains explains explains explains explains explains explains negative. explains negative explains negative negative. organization explains and
#
# Input Sentence: I enjoy the class because the instructor keeps the students engaged and is able to explain the content in a way that keeps me interested. The instructor also has broad knowledge on the subject and can explain it well. Also, I appreciate that the instructor
# Predicted Sentence: The sentiment polarity of instructor and adaptation is neutral. topic] explains]]]]] language] explains explains explains negative explains explains organization negative negative is explains organization explains is pol is explains explains. negative explains organization is explains
#
# Input Sentence: Like, please ask for the quiz at the end of the period.
# Predicted Sentence: The sentiment polarity of motivation and adaptation is neutral. topic topic topic explains]] topic topic explains sentiment] explains explains explains organization language organization language explains organization organization. organization is negative negative explains language explains
#
# Input Sentence: [Instructor] visited me very warmly and professionally every time I requested support.
# Predicted Sentence: The sentiment polarity of content usability is neutral.]ad] explains]]]]us explains explains explains explains language explains very negative explains explains explains negative explains explains. topic. explains organization is explains explains is explains explains pol explains
#
# Input Sentence: The teacher taught is a little too fast.
# Predicted Sentence: The sentiment polarity of instructor is neutral.]]]]]] explains]]]] explains explains]]]] explains explains explains explains explains pol explains explains]ad explains explains explains explains explainsad explains explains
#
# Input Sentence: The teacher should have more time to check the name.
# Predicted Sentence: The sentiment polarity of re is neutral.]]]]] is] explains] explains] explains]] explains sentiment sentiment explains explains sentiment explains explains topic explains explains explains sentiment explains sentiment organization explains organization explains organization is
#
# Input Sentence: I think we can enter [the subject] faster. It is just pitiful that we only learn the modern [subject] than last week.
# Predicted Sentence: The sentiment polarity of interaction goal alignment is neutral.] topic]]]]]] explains topic language] explains explains] explains language explains] pol. negative. explains negative is pol. explains explainsarity. explains.
#
# Input Sentence: For 1.2 I think that you provide the link to the video that you have opened during the class because it is PDF files and we can only see the picture. Another thing is the activity document.You should check whether [software]
# Predicted Sentence: The sentiment polarity of re is neutral.] language] explains]]]]] explains explains explains negative is explains]] explains]] explains explains explains explains explains. negative negativearity organization is explains explains language explains is explains
#
# Input Sentence: Too much work
# Predicted Sentence: The sentiment polarity of instructorusability is neutral.] topicarity]]] explains explains language sentiment explains language negative] organization explains explains explains explains organization organization language. explains organization sentiment is negative. explains explains organizationusarityarity organization organization
#
# Input Sentence: [instructor] is impolite sometimes, teaches not well, very little people show up in the class because they have no clue what they're studying and they do not find learning with  [instructor] enjoying or easily
# Predicted Sentence: The sentiment polarity of reusability is neutral. negative]]]] language]] explains] explains explains]]] negative] negative explains] explains explains explains explains pol negative explains is negative pol topic explains organization negative explains
#
# Input Sentence: AJ explain unclear every time he gives homework and [instructor] my question in email or [system] slowly.
# Predicted Sentence: The sentiment polarity of re is neutral.]] topic] explains]] explains]ad]arity] topic explains explains] organization explains explains explains]. organization negative organization topic explains is negative explains. is.
#
# Input Sentence: He is a good teacher. I see my change, thank you Kubb!
# Predicted Sentence: The sentiment polarity of instructorusability is neutral. explains] explains]]]]] explains is] explains organization. explains explains explains organization explains explains explains is explains organization organization negative. organizationarity explains explains negative explains explains
#
# Input Sentence: The teacher does not have the responsibility to prepare the slideshow, because we waste time for this hour of 30 hours of 30 minutes. [The instructor] did not speak clearly in class. I don't understand that he wants until'To what
# Predicted Sentence: The sentiment polarity of instructor usability is neutral.] explains]] pol]]]]] negative explains explains explains explains explains explains explains sentiment sentiment explains] topic negative explains sentiment. negative negative is. explains explains explains explains explains sentiment
#
#
#
# Input Sentence: There should be more hour studying this course.And there is a problem similar to the exam to practice
# Predicted Sentence: The sentiment polarity of content and adaptation is neutral.]]]]] explains] sentiment]] explains] explains explains] explains explains] explains explains explains negative negative negative negative. is organization negative is language and. pol organization
#
# Input Sentence: Too much homeworkThere are every week.
# Predicted Sentence: The sentiment polarity of re goal alignment is neutral.] topic is]]]]]]] explains organization explains negative] negative language language is organization negative] explains negative is negative is explains language explains language explains organization
#
# Input Sentence: Change the way U taught, not copy from book. Make it simplify and easy for student to learn.
# Predicted Sentence: The sentiment polarity of feedback and adaptation is neutral.]]]]]]ad topic negative explains is organization explains] negative explains organization explains negative pol negative organization organization organization explains explains organization. negative organization explains language explains organization
#
# Input Sentence: 48 [Topic] sent by that night too much
# Predicted Sentence: The sentiment polarity of re and adaptation is neutral.]]]]]]]]]] explains sentiment explains organization explains explains] sentiment explains explains explains. explains organization explains negative organization organization explainsarity negativearity organization explains language sentiment
#
# Input Sentence: Add more cultural evolution of technology
# Predicted Sentence: The sentiment polarity of re is neutral. language explains]]]] is]] explains explains explains is topic is]] explains is is is is explains explains very is is. organization language negative is
#
# Input Sentence: The teacher gives a snack when resting during the class and asking students if they can do it or not.Master cares well.
# Predicted Sentence: The sentiment polarity of motivation usability is neutral.] topic] language]]]] explains topic] negative. explains explains] explains language language explains negative language. explains explains is is pol organization. is. explains
#
# Input Sentence: He was not clear to assign homework, and he never adapted to him. I commented in [subject] in the same problem.
# Predicted Sentence: The sentiment polarity of re is neutral.]]]]]]]] language] sentiment is explains explains explains explains sentiment] organization explains explainsases negative explains negative explains negative explains negative topic topic organization language. language explains
#
# Input Sentence: Please have more flexibility on hybrid courses (online + on site)
# Predicted Sentence: The sentiment polarity of learning and adaptation is neutral.] explains] explains]]]]] explains explains explains. negative explains explains explains organization negative negative. organizationarity isarity explains negative explains organization organization
#
# Input Sentence: Instructor often ignor student's question and things being asking regarding the class never been replyed.
# Predicted Sentence: The sentiment polarity of reusability is neutral.] topic]]]]]]] is] is] explains explains. negative topic negative]... explains explains is organization.] explains.
#
# Input Sentence: During my contact with [instructor] I was able to see that [trainers] is a very efficient academic. [Instructor] Knowledge and experience are certainly extensive
# Predicted Sentence: The sentiment polarity of instructor is neutral.].]]]]]]]] is] isarity] organization explains explains organization explains pol organization explains explains explains is explains explains pol explains] pol
#
# Input Sentence: Great explanation on class material. See the more interesting and more funny class.
# Predicted Sentence: The sentiment polarity of learningusability is neutral.]]]]]]] explains] explains]] explains negative negative sentiment pol explains explains is topic explains explains. explains organization organization explains explains explains.. organization explains
#
# Input Sentence: Good trainer, informative course
# Predicted Sentence: The sentiment polarity of learning usability is neutral.]] topic]]]]]] explains] explains explains explains negative explainsarity explains explains language negative negative explains is is is is. organization pol negative explains negative negative organization topic
#
# Input Sentence: The mid-term examination has a lot of calculation, I think that a calculator should be authorized because we are tested for our [course] skills and not our calculation skills.
# Predicted Sentence: The sentiment polarity of learning usability is neutral.]]]] explains]]]] explains explains explains negative explains explains negative explains negative negative explains is language explains explains topic explains organization explains organization. organization
#
# Input Sentence: Good teaching skills, very flexible
# Predicted Sentence: The sentiment polarity of instructor quality is neutral.]]] explains explains] is explains] explains explains] explains sentiment] explains explains explains explains explains negative sentiment negative negative explains explains explains very is sentiment sentiment explains explains explains explains explains explains
#
# Input Sentence: Finding terms and vocabs is useless.
# Predicted Sentence: The sentiment polarity of instructor is neutral.arity]] explains is] is is is]] language explains explains pol explains explains organization negative explains explains sentiment explains is explains. explains sentiment explains negative explains. negative explains languageords explains is
#
# Input Sentence: [Trainer] is a very good teacher for me. [Trainer] always give a clear feedback for my work. [Trainer] Answer the massage very quickly, which helps me to do the task smoothly. I am so happy
# Predicted Sentence: The sentiment polarity of learning usability is neutral.]]]] explains]]] explains explains explains explains explains] isarity language sentiment explains organization explains topic pol explains explains negative negative pol explains explains explains explains explains is organization explains
#
#
#
# Input Sentence: I believe that this subject presents many advantages, but the workload is too much for students compared to other classes. Even when it is almost the week of exams, this class always requires us to subject work. So thinkthat assignments must be reduced
# Predicted Sentence: The sentiment polarity of re goal alignment is neutral.] is]]]]]]] explains] is is explains explains explains is negative explains explains pol explains explains pol negative explains explains explains organization explains
#
# Input Sentence: Very punctual and strict to the point
# Predicted Sentence: The sentiment polarity of re is neutral.]]]]]]]]]]]]arity explains explains explainsare sentimentarity explains explains] organization negative organization explains sentiment organization explains explains is is topic. organization explains explains
#
# Input Sentence: This course is very difficult expecially the last part. I think there should be some adjustment to the cirriculum and maybe exclue some topic. Some topics are too complicated to be taught in an entry level class in my opinion.
# Predicted Sentence: The sentiment polarity of re is neutral. negative.]]] topic]]]]]]]] explains explains explains explains explains explains explains negative explains explains explains organization organization] is. organization negative explains organization.
#
# Input Sentence: The emphasis [of the instructor] is difficult to understand a lesson.
# Predicted Sentence: The sentiment polarity of re quality is neutral.]]]]]]]] explains explains] is is]] explains negative organization organization is explains. explains organizationarity explains language explains explains
#
# Input Sentence: please listen to students opinion more
# Predicted Sentence: The sentiment polarity of re and adaptation is neutral.arity topic]]]]]]] explains] organization explains explains explains] very explains]] explains is negative] negative explains explains organization explains
#
# Input Sentence: An advanced subject in [courses] and [the subject] is very difficult.
# Predicted Sentence: The sentiment polarity of re quality is neutral.]]] explains]]]]] explains explains sentiment explains]arity sentiment] explains negative explains. negative organization. isarity. negative explains negative.. negative explains.
#
# Input Sentence: Order additional class
# Predicted Sentence: The sentiment polarity of re is neutral.]]] explains]]] organization]] explains explains]] explains] explains explains explains explains organization explains sentiment pol sentiment negative negative] explains explains organization explains explains is explains
#
# Input Sentence: Advanced topic in the [course] and [topic] is very difficult.
# Predicted Sentence: The sentiment polarity of re is neutral.] explains] explains]]]] sentiment very explains explains explains is explains sentimentarity organization explains sentimentarity is explains sentiment language explains language is language organization language sentiment explains sentiment is
#
# Input Sentence: maybe he is good in teaching in Thai language morethan explains things in english.
# Predicted Sentence: The sentiment polarity of organization is neutral.]] explains]]]]. sentiment explains explains explains sentiment and sentiment sentiment is explains explains explains negative explains organization very sentiment sentiment negative negative is explains sentiment explains is explains sentiment organization organization
#
# Input Sentence: Deciding to host onsite classes and her only appearing in online meetings is one of the worst experiences I have ever felt, sure, [instructor] may have health issues but could have hosted online classes. To add an insult to
# Predicted Sentence: The sentiment polarity of re quality is neutral.arity explains sentiment]]] is]arity explains]] explains explains explains] explains explains explains explains negative negative is explains explains is is organization explains organization language organization organization
#
# Input Sentence: Please let students have attendance checks while some phones aren't capable to scan from some distance or have another way for attendance
# Predicted Sentence: The sentiment polarity of instructor is neutral.] topic]]]]]]] explains explains explains explains explains organization explains explains explainsarity organization sentiment is explains explains explains sentiment explains explains explains explains pol explains explains, sentiment explains
#
# Input Sentence: This course is very difficult especially the last part. I think there should be an adjustment to the cirriculum and perhaps exclude a subject. Certain subjects are too complicated to be taught in an entry-level class in my opinion.
# Predicted Sentence: The sentiment polarity of instructor quality is neutral.]]] is] explains]] negative sentiment explains explains explains explains explains]] sentiment explains negative negative negative organization sentiment. is language negative explainsary. sentiment negative organization. explains
#
# Input Sentence: I think the lesson is too difficult to absorb, however, I will do my best to understand these things!
# Predicted Sentence: The sentiment polarity of re is neutral..]]]]]] explains languagearity explains explains sentiment language explains sentimentare sentiment explains] explains explains negative is language explains explains is language negative organization sentiment is.
#
# Input Sentence: too many hw. Isn't it just an elective course?
# Predicted Sentence: The sentiment polarity of instructor quality is neutral.] explains is]]] explains]] explains explains explains negative explains language explains explains explains sentiment explains explains sentiment sentiment explains explains negative negativearity is language organization language explains is
#
# Input Sentence: Order additional class
# Predicted Sentence: The sentiment polarity of content is neutral.] topic explains explains is]]]] explains sentiment explains] explains sentiment]] sentiment explains sentiment explains sentiment explains sentiment explains explains sentiment sentiment explains explains organization language sentiment is explains is
#
# Input Sentence: Thank you for having [instructors] as our consultant. [Trainer] is really a beautiful mentor. [Trainer] gave us many effective and selective comments so that we can understand and improve in a not too stressful atmosphere.
# Predicted Sentence: The sentiment polarity of instructor usability is neutral.]]]]]]]]] explains. is explains explains very explains] sentiment explains explains language explains. organization. negative organization pol explains explains organization organization explains
#
#
#
# Input Sentence: I believe that this topic has a lot of advantages, but the workload for students compared to other classes is too much. If it is almost an exam week, we have to submit work after this class. I think tasks should be less with
# Predicted Sentence: The sentiment polarity of instructor usability is neutral.arity]]]] explains] explains explains]] sentiment is organization explains explains explains explains explains explains explains explains explains negative is negative] topic. negative explains explains
#
# Input Sentence: A great teacher, very attentive and respectful. Fortunately, the lessons are generally the evening of the day. Another side, the workloads on other subjects reduce the time that we can spend with the friends of the study andConsiderate self-
# Predicted Sentence: The sentiment polarity of re is neutral.]]]]]]]]]]]] explains explains]] negative explains explains negative explains negative negative explains explains organization explains. is. organization explains] explains explains organization explains explains
#
# Input Sentence: Change the way U taught, not copy from book. Make it simplify and easy for student to learn.
# Predicted Sentence: The sentiment polarity of learning goal alignment is neutral.]] is is]]]]] explains explains explains explains] explains language explains topic topic. organization negative organization. explains organization explains explains explains explains organization is
#
# Input Sentence: I really enjoy your lectures, your style of teaching is highly interesting and entertaining.
# Predicted Sentence: The sentiment polarity of re goal alignment is neutral.]]]]]]] is] explains explains explains explains sentiment explains sentiment explains topic explains sentiment explains negative is explains explains explains organization explains
#
# Input Sentence: I think that [instructor] accent is hard to understand
# Predicted Sentence: The sentiment polarity of re usability is neutral.]]] explains]]]]] explains explains explains] explains explains is explains explains explains explains explains explains organizationarity organization explains explains explains is isarity organization. explains
#
# Input Sentence: great teacher, very caring and respectful. unfortunately the classes are usually at the evening of the day. on the other hand, the workloads on other subjects redusce the time we can spend with the study buddies and self-learning significantly
# Predicted Sentence: The sentiment polarity of instructor is neutral.]]]]]]]]]] language] explains explains explains] negative explains explains] sentiment language topic topicarity explains negative negative organization explains negative. organization organization explains organization
#
# Input Sentence: Sometimes I didn't catch the content when they went too quickly.
# Predicted Sentence: The sentiment polarity of reusability is neutral.] topic] explains] explains]]arity explains explains explains explains explains topic topic negative. explains negative very pol sentiment.
#
# Input Sentence: I can't understand what the teacher taught
# Predicted Sentence: The sentiment polarity of learning is neutral.arity] explains]ad is explains]] explains explains explains explains explains explains explains language explains sentiment explains explains explains explains explains, explains explains organization negative explains explains is organization negative organization explains
#
# Input Sentence: TA is very efficient.
# Predicted Sentence: The sentiment polarity of content is neutral. sentiment]] explains explains]]] sentiment sentiment explains explains explains, explains explains explains sentiment explains explains negative topic explains sentiment] organization negative sentiment explains explains is organization,
#
# Input Sentence: Too much hw.n is not just an elective course?
# Predicted Sentence: The sentiment polarity of reusability is neutral.arity]] explains]]]] language explains]] explains explains explains explains explains explains explains sentiment language explains negative organization language explains explains explains explains language organization is explains explains
#
# Input Sentence: Add more technology cultural evolution
# Predicted Sentence: The sentiment polarity of re usability is neutral..]]]]]]] explains language language]. negative negative explains pol.arity explains explains explains pol explains organization explains explains negative explains.ans explains
#
# Input Sentence: I want the teacher to tell clearly the lesson that will be learned because sometimes I am a little confused what we learn now. And I want the teacher to teach on the slides because I can obviously not see the scriptures on a board
# Predicted Sentence: The sentiment polarity of re goal alignment is neutral.us explains topic.]]] organization]] explains] explains. explains explains explains negative is.. explains organization negative negative explains language, explains explains organization explains
#
# Input Sentence: [The instructor] is rude sometimes, do not teach well, very few people appear in the classroom because they have no idea what they study and they do not find learning with [theInstructor] Taking advantage or easily understandable. The method
# Predicted Sentence: The sentiment polarity of instructor and adaptation is neutral.]]]]]]]] is negative topic explains] sentiment. negative sentiment explains explains negative explains negative explains.. language explains explains language is explains
#
# Input Sentence: I appreciate your teaching! and everything, thanks for teaching us!
# Predicted Sentence: The sentiment polarity of re usability is neutral. negative pol] topic]] is]] explains explains] explains explains explains explains explains explains explains negativearity language explains explains explains explains organization explains. explains explains explains
#
# Input Sentence: Remove this topic
# Predicted Sentence: The sentiment polarity of feedback goal alignment is neutral.]]]]]]]]] explains explains explains]] explains explains organization language organization sentimentare is negative explains organization explains language. is organization organizationarity
#
# Input Sentence: I think this course is very good, and I love it so much. Aj teaches and treats very well.
# Predicted Sentence: The sentiment polarity of learning quality is neutral.] explains] is] is] negative is. organization is negative. explains pol explains is explains explains organization explains explains.
#
#
#
# Input Sentence: Everything is fantastic, except to use the [system] for work.
# Predicted Sentence: The sentiment polarity of learningusability is neutral.]]]]]]]] language explains] explains explains] explains explains explains explains explains explains explains negative explains explains explains organization organization. language negative. explains. explains
#
# Input Sentence: I also could not memorize the whole structure and find myself very difficult with the subject. However, one night, by my compassion and a liter of coffee, I decided to revise the [lessons] of the lastSemester from the
# Predicted Sentence: The sentiment polarity of content and adaptation is neutral.]]]]]]]]]]]]]]]] explains organization explains] explains very sentimentarity negative explainsarity is explains sentiment explains explains sentimentarity.
#
# Input Sentence: I like the teacher very much. I understand. I know about it, but because I am not very practicing so I can't do it.
# Predicted Sentence: The sentiment polarity of re quality is neutral.]] is is] explains topic]]] language negative explains topic topic] pol explains explains. negative negative negative is is is sentiment explains. is
#
# Input Sentence: Would like the teacher to teach more interesting
# Predicted Sentence: The sentiment polarity of re and adaptation is neutral. topic topic] explains]]] explains explains explains explains explains is] explains explains explains explains explains explains explains organization language sentiment negative is explains] explains explains explains..
#
# Input Sentence: The teacher has no responsibility for the preparation of the film, since we waste time for this 1 hour of 1 hour of 30 minutes. [Trainer] did not clear in the classroom. I don't understand anything until I think I think
# Predicted Sentence: The sentiment polarity of re usability is neutral. negative]]]]]]]] negative explains explains explains explains explains] explainsarity organization organization organization is is explains organization negative is
#
# Input Sentence: [instructor] accent is hard to understand a lesson.
# Predicted Sentence: The sentiment polarity of instructor is neutral.]]]]]] is]arity language explains explains explains] sentiment negative explains sentiment sentiment sentimentarity language explains] negative sentiment sentiment language pol is pol sentiment explains is explains is language language
#
# Input Sentence: I like your class very much. It is very great for us. I received a lot of opinions in your class. Thank you beautiful!!
# Predicted Sentence: The sentiment polarity of instructor is neutral.] explains] is]]] is is explains explains] sentiment is explains explains explains explains explains negative negative explains explains explains negative is explains sentiment explains is explains pol explains explains explains explains
#
# Input Sentence: Illustrated about examination
# Predicted Sentence: The sentiment polarity of organization is neutral.us] explains]] negative]]] is explains] explains] explains explains explains explains explains explains explains organization explains explains is sentiment polarity explains pol
#
# Input Sentence: Many workloads
# Predicted Sentence: The sentiment polarity of re usability is neutral.]]]]]]] language explains]]] explains explains organization explains explains explains explains explainsarityarityarity pol explains organization explains pol organization
#
# Input Sentence: The conference is easy to understand after the instructor taught.
# Predicted Sentence: The sentiment polarity of re is neutral.]]]]]]]] is] sentiment topic language] explains is explains explains languagearity sentiment explains topic explains explains sentiment is, sentiment explains explains isusus negative is languagearityarity
#
# Input Sentence: For 1.2, I think you should provide the link to the video you opened during class because they are PDF files and we can only see the image. Another thing is the activity document, you must checkwhether [software] is the
# Predicted Sentence: The sentiment polarity of learning is neutral.].]] is is is is explains] is negative explains explains explains explains explains explains explains negative explains explains pol is. explains topic is explains explains organization organization negative
#
# Input Sentence: I think we qui when the class starts better than we go to the faculty to take 15 minutes from quiz because I take about 2 hours to come to the ability to my house.
# Predicted Sentence: The sentiment polarity of instructor is neutral.]] explains]] explains]]] explains explainsad explains explains explains explains explains explains sentiment organization sentiment explains organization explains explains is explainsarity negative negative organization organization explains organization explains is explains.
#
# Input Sentence: Great teaching skills, really take care of students
# Predicted Sentence: The sentiment polarity of instructor quality is neutral.]]]] explains] topic]]] explains explains explains explains explains is explains explains is] explains explains explains explainsarity pol sentiment explains explains. explains explains explains explains
#
# Input Sentence: A great teacher, very attentive and respectful. Fortunately, the lessons are generally the evening of the day. Another side, the workloads on other subjects reduce the time that we can spend with the friends of the study andConsiderate self-
# Predicted Sentence: The sentiment polarity of interactionusability is neutral.]]]]]] explains] explains explains] explains is explains explains is explains explains explains. explains is negative negative explains explains explains very language explains organization
#
# Input Sentence: Please have more flexibility on hybrid courses (online + on site)
# Predicted Sentence: The sentiment polarity of re goal alignment is neutral.]] explains]]] explains language] explains]] topic explains is explains explains explains slides is explains is topic,.] organization organization topic is
#
# Input Sentence: The content in the subsequent parts of the course is very difficult to understand. I ask myself if one of my friends includes 60%.
# Predicted Sentence: The sentiment polarity of instructor goal alignment is neutral. topic] topic]]]] is] is] explains is is is sentiment organization topic language language pol explains explains sentiment. explains negative organization explains explains explains language explains explains is
#
#
#
# Input Sentence: Add more technology cultural evolution
# Predicted Sentence: The sentiment polarity of instructor and adaptation is neutral.]] is]]]]arity explains is] is. explains] explains explains organization. explains is explains is explains explains explains organization. is. explains language organization
#
# Input Sentence: The content in later parts of the course are very hard to understand. I wonder if any of my friends understand 60% of it.
# Predicted Sentence: The sentiment polarity of instructor goal alignment is neutral. topic topic]] explains]] is explains explains is organization] language explainsarity explains explains pol explains pol explains is isarity organization. organization] organization sentiment sentiment organization is is
#
# Input Sentence: During my contact with [instructor], I could realize that [instructor] is a very efficient academic. [instructor] knowledge and experience is certainly extensive
# Predicted Sentence: The sentiment polarity of instructorusability is neutral.]] is]]]]]]] explains]] explains explains pol explains explains negative language explains negative is explains explains explains negative negative organization explains explains
#
# Input Sentence: Good instructor, informative courses
# Predicted Sentence: The sentiment polarity of learning usability is neutral.]]]]]]]] explains explains is sentimentarity explains explains negative negative... topic. is explains explains explains explains explains organization
#
# Input Sentence: Continue with this teaching method
# Predicted Sentence: The sentiment polarity of instructor goal alignment is neutral.]]]]]] is pol language explains explains explains] explains explains.] is explains explains negative is organization is language is.
#
# Input Sentence: Sometimes I didn't catch the content if you went too fast.
# Predicted Sentence: The sentiment polarity of instructor and adaptation is neutral. sentiment. pol.arity negative.arityarity negativearity negative negative negative positivearityarity pol. sentiment. polarity negativearity. pol negative negative negative neutral negative negative negativearity. pol
#
# Input Sentence: It would be preferable that we have the permanent class calendar. Spare each class for each section can be more effective.
# Predicted Sentence: The sentiment polarity of instructor is neutral. explains explains is explains. explains explains explains organization explains explains negative explains negative explains explains explains explains. explains explains is explains explains explains explains explains explains topic., is explains
#
# Input Sentence: Good trainer, informative course
# Predicted Sentence: The sentiment polarity of organization quality is neutral.arity] explains explains] explains] explains organization explains explains explains explains is explains explains explains is explains. explains explains is explains. negative is is organization explains explains. sentiment explains explains
#
# Input Sentence: During my contact with [the instructor], I could realize that [the instructor] is a very effective academic. [Instructor] Knowledge and experience are certainly extended
# Predicted Sentence: The sentiment polarity of organizationusability is neutral. topic]]]]]]]]] explains]]] explains topic explainsarity organization explains negative explains explains topic organization. negative topic explains is language negative explains explains is organization is
#
# Input Sentence: The air conditioner in the lab is very cold.Would like the table to be wider than this when placing the box [Course] and the laptop
# Predicted Sentence: The sentiment polarity of reusability is neutral. topic]]]]]]]] explains explainsarity explains explains explainsarity explains language]] negative explains organization very negative negative explains language is organization explains.arity
#
# Input Sentence: I like the comments in real time that [the instructor] gave during the lessons.
# Predicted Sentence: The sentiment polarity of learningusability is neutral.]] explains]]]]]] explains explains] explains explains explains explains explains language negative pol is organization negative] is explains organization negative language is language topic
#
# Input Sentence: First, it is quite difficult to learn, but I see that Ajarn is trying to understand the students and also wait for us to teach the notes, thank you.
# Predicted Sentence: The sentiment polarity of instructor and adaptation is neutral.]] explains]]]] explains] explains sentiment explains is]] explains explains explains explains. organization language explains pol topic negative negative explains negative negative. explains explains
#
# Input Sentence: I suggest that laboratory learning or with computer always helps students learn better.
# Predicted Sentence: The sentiment polarity of reusability is neutral.]] language]]]]]] explains explains explains explains] organization] pol explains explains. explains explains explains explainsarity explains language explains explains explains organization negative explains explains explains explains
#
# Input Sentence: Please listen to the opinion of the students more
# Predicted Sentence: The sentiment polarity of feedback usability is neutral. and]]]]]] is]]] is explains explains explains explains explains explains explains explains organization explains topic explains explains negative explains explains explains is is explains explains explains explains is
#
# Input Sentence: Please have the students present present, while some telephones are unable to scan from a distance or to have another option for the presence
# Predicted Sentence: The sentiment polarity of re usability is neutral.]]]]]]]]]] explains language is explains explains explains explains explains explains] organization negative explains language negative explains.. explains. language topic explains
#
# Input Sentence: Could use the slide that does not contain united color as a blue or black background because when students must print the equipment for the exam, they are difficult to read or must print it using the ink ofColor or could AJ please give the slide
# Predicted Sentence: The sentiment polarity of feedback quality is neutral.]]]]]]]]] explains explains is explains explains].. organization explains organization language negative. is organization. negative is organization organization
#
#
#
# Input Sentence: The lecture is easy to understand after the instructor has taught.
# Predicted Sentence: The sentiment polarity of motivation goal alignment is neutral. is]]]]]]]] is explains. explains explains topic] explains explains.. is negative] organization..arity negative. organization explains explains
#
# Input Sentence: Please extend the period assignment deadline by a day.
# Predicted Sentence: The sentiment polarity of feedback is neutral.]]]]]]]]] explains sentiment explains explains] explains explains explains language explains explains] explains] explains explains sentiment negative explains negative sentiment explains language explains pol
#
# Input Sentence: Go on with this teaching method
# Predicted Sentence: The sentiment polarity of motivation usability is neutral.]] explains]]] is]] explains explains]] explains language explains explains explains pol explains explains explains explains explains language sentiment explains organization negativearity organization explains
#
# Input Sentence: The recording is not provided, but I do urge academic affairs to provide the recordings so that the students may be able to revise the material on their own.
# Predicted Sentence: The sentiment polarity of instructor goal alignment is neutral.]] explains]]] explains is]] explains] explains explains explainsad explains organization explains explains explains explains. explains negative negative explains is organization topic explains explains.
#
# Input Sentence: Deadline for assignment is too short. 72 hours is a short time compared to other subject which give you at least 1 week to finish the assignment. Also, I thought I'd learn [topic] and not [topic]....
# Predicted Sentence: The sentiment polarity of instructor quality is neutral.] explainsad]]]]] language]] pol explains explains organization. sentiment explains sentiment] language explains explains organization explains organization. explains negative explains very explains organization, sentiment organization is
#
# Input Sentence: I believe that a few short breaks would not affect the river of the class during the 3 -hour lesson, so I would like to suggest that students take some breaks during the lesson.
# Predicted Sentence: The sentiment polarity of re usability is neutral. negativearity] topic]]]]] sentiment negative explains explains] is explains organization explains very explains explains explains explains explains explains explains sentiment explains topic negative explains. explains organization organization pol negative organization
#
# ...
#
# Input Sentence: I also could not memorize the whole structure and find myself very difficult with the subject. However, one night, by my compassion and a liter of coffee, I decided to revise the [lessons] of the lastSemester from the
# Predicted Sentence: The sentiment polarity of re goal alignment is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: Will be even better if thereoutline in the work sectionSo that students will focus on the topic that the course needs moreBut if in order to think, study, research, find the necessary information by yourself, now is ok
# Predicted Sentence: The sentiment polarity of interaction is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol polarity pol pol pol pol pol pol pol pol
#
# Input Sentence: During my contact with [the instructor], I could realize that [the instructor] is a very effective academic. [Instructor] Knowledge and experience are certainly extended
# Predicted Sentence: The sentiment polarity of instructor quality is neutral. polarity pol pol.. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol polarity pol pol pol pol pol pol pol pol pol
#
# Input Sentence: I felt like it's hard to get full picture of what's going on in the lecture class. It'd be better if the entire class is writing code together on the computer during lecture, then let everyone do their own lab afterward. That
# Predicted Sentence: The sentiment polarity of interaction is neutral. pol pol pol pol pol pol pol] pol pol pol pol pol polarity pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: Good course, learning many things, even teammate does not work very well as expected.
# Predicted Sentence: The sentiment polarity of reusability is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol polarity pol pol pol pol pol pol pol pol
#
# Input Sentence: I want to thank you for each time that Jarn gives me advice. You are the best!
# Predicted Sentence: The sentiment polarity of interaction quality is neutral. pol... pol.. pol. pol pol pol. pol pol pol pol pol pol pol. pol pol. pol pol pol pol pol. pol pol pol pol pol pol. pol
#
# Input Sentence: I think this course is really important for future work. If students can digest the class content, it would be very beneficial for them.
# Predicted Sentence: The sentiment polarity of re is neutral. pol pol. pol.. pol. pol pol pol pol pol. pol pol pol. pol pol. pol pol pol pol pol pol pol pol.. pol pol. pol. pol pol pol
#
# Input Sentence: I believe that this subject has many benefits but the workload is too much for students compared to other classes. Even when it’s almost exam week, this class still requires us to submit work. So I think assignments should be cut less
# Predicted Sentence: The sentiment polarity of interaction goal alignment is neutral. pol pol pol pol. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol. pol
#
# Input Sentence: I like the way you teach us a lot, as well as the suggestions and descriptions. This helps us a lot to understand each assignment more clearly. In addition, I see effort and dedication in teaching.merci.j 'hope
# Predicted Sentence: The sentiment polarity of organization goal alignment is neutral. pol. pol pol. pol polarity pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: I really enjoy your lectures, your style of teaching is highly interesting and entertaining.
# Predicted Sentence: The sentiment polarity of instructor is neutral. pol pol pol pol pol pol pol pol pol pol pol pol sentiment is pol pol pol pol sentimentarity pol pol pol pol pol pol pol pol. pol pol pol pol pol pol pol pol pol pol
#
#
#
# Input Sentence: The instructor must prepare equipment and a platform for student students and the more appropriate laboratory.
# Predicted Sentence: The sentiment polarity of interaction is neutral. pol... pol.... pol pol pol. pol pol pol pol pol pol pol.. pol pol pol pol pol pol pol.. pol pol pol pol pol. pol pol
#
# Input Sentence: The workload is unbalanced and too much to be handled. A certain assignment is not nectar and waste. Several individual tasks look like a project.B. to have the report, 20 pages, summarized more than two pages. I think
# Predicted Sentence: The sentiment polarity of interaction is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol. pol pol pol pol
#
# Input Sentence: The assignment sometimes does not really make sense.
# Predicted Sentence: The sentiment polarity of learning usability is neutral. pol pol. pol. pol.. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: The slides given have too many words, formulas, and diagrams, and I am overwhelmed by them.
# Predicted Sentence: The sentiment polarity of re is neutral. pol... pol pol pol pol pol pol pol pol pol pol pol pol pol pol. pol. pol pol pol pol. pol. pol... pol. pol pol pol..
#
# Input Sentence: For 1.2 I think that you provide the link to the video that you have opened during the class because it is PDF files and we can only see the picture. Another thing is the activity document.You should check whether [software]
# Predicted Sentence: The sentiment polarity of organization and adaptation is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: The workload is unbalanced and too much to be handled. A certain assignment is not nectar and waste. Several individual tasks look like a project.B. to have the report, 20 pages, summarized more than two pages. I think
# Predicted Sentence: The sentiment polarity of instructor goal alignment is neutral. pol pol pol pol] pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol negative pol pol pol. pol pol pol pol pol pol pol pol pol
#
# Input Sentence: Change the assignment because in the real world, we use [the library], [the library] not necessary to make recursive or something like that.
# Predicted Sentence: The sentiment polarity of interaction goal alignment is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: Would like to have more work as a HW than the exam
# Predicted Sentence: The sentiment polarity of re goal alignment is neutral. pol pol pol. pol. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol. pol pol pol pol pol pol pol pol pol
#
# Input Sentence: I love teachers because you have read our work in front of Q@& A session so that you can give good feedback
# Predicted Sentence: The sentiment polarity of interaction is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: The instructor should prepare materials and platform for student can student and do the lab more appropriate.
# Predicted Sentence: The sentiment polarity of instructorusability is neutral.] pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: The teacher gives a snack when resting during the class and asking students if they can do it or not.Master cares well.
# Predicted Sentence: The sentiment polarity of organization quality is neutral. pol. pol pol pol. pol.. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: The teachings [of the instructor] are quite confusing, yes, the material [courses] itself is very difficult, but the style of teaching [instructor] makes it quite difficult to understand the meaning, to add to this that
# Predicted Sentence: The sentiment polarity of instructor is neutral.arity pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol] pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol polarity pol
#
# Input Sentence: Ajarn should not speak for the duration of the quiz
# Predicted Sentence: The sentiment polarity of interaction quality is neutral. pol. pol. pol pol pol pol pol pol pol pol pol pol pol pol. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol. pol
#
# Input Sentence: Deciding to welcome courses on site and its appearance only during online meetings is one of the worst experiences that I have never felt, surely, [the instructor] can have health problems but could have organized coursesOnline. To add an insult to
# Predicted Sentence: The sentiment polarity of organization goal alignment is neutral. pol pol pol pol pol] pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol negative pol pol pol pol pol
#
# Input Sentence: The projects are difficult, it will be more pleasant if we have more time to do so.
# Predicted Sentence: The sentiment polarity of interaction is neutral........ pol pol...... pol pol pol.... pol pol pol pol pol pol pol pol pol pol pol pol.. pol pol pol
#
# Input Sentence: I really like the way [the instructor] listens to students [instructor] and adaptable
# Predicted Sentence: The sentiment polarity of instructorusability is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
#
#
# Input Sentence: Please extend the deadline for allocating the period of a day.
# Predicted Sentence: The sentiment polarity of re and adaptation is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol. pol pol pol pol pol pol pol
#
# Input Sentence: I believe that this subject presents many advantages, but the workload is too much for students compared to other classes. Even when it is almost the week of exams, this class always requires us to subject work. So thinkthat assignments must be reduced
# Predicted Sentence: The sentiment polarity of re quality is neutral. pol pol pol pol. pol pol pol pol pol pol pol pol pol pol. pol pol pol pol. pol pol pol pol pol pol pol pol pol pol pol pol pol pol polarity.
#
# Input Sentence: Like in the entry of the work of the instructorThe teacher uses a variety of boring tones and teaching.Makes me feel that this course is worth studyingAs well as allowing students to participate in the opinion or have reaction
# Predicted Sentence: The sentiment polarity of interaction goal alignment is neutral.ability pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol. pol pol pol pol pol pol pol pol
#
# Input Sentence: Instructor often ignor student's question and things being asking regarding the class never been replyed.
# Predicted Sentence: The sentiment polarity of learning and adaptation is neutral. pol pol pol pol pol pol pol pol pol goal pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: Too many hw. is not just an election course?
# Predicted Sentence: The sentiment polarity of interaction goal alignment is neutral. pol pol] pol pol pol pol pol pol pol pol pol pol polarity pol pol pol pol pol pol pol pol pol. pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: great teacher, very caring and respectful. unfortunately the classes are usually at the evening of the day. on the other hand, the workloads on other subjects redusce the time we can spend with the study buddies and self-learning significantly
# Predicted Sentence: The sentiment polarity of learning is neutral. pol.. pol pol pol pol pol pol pol pol pol pol. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol. pol. pol pol pol pol pol.
#
# Input Sentence: The teacher taught very well.
# Predicted Sentence: The sentiment polarity of interaction goal alignment is neutral.] pol pol.. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: I think this course is really important for future work. If students can digest the class content, it would be very beneficial for them.
# Predicted Sentence: The sentiment polarity of organization usability is neutral.] pol pol pol pol. pol pol pol pol pol pol pol pol pol pol polarity pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: I think that the instructor should explain the content more detail because I could not understand several parts of the lectures.is complicated for several parts. Yede film introduced a new topic, and I was able to contain the overall picture of the topics
# Predicted Sentence: The sentiment polarity of learning usability is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: Too much work and why you assign project before final.
# Predicted Sentence: The sentiment polarity of learning and adaptation is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: It would be great if we can get more information about the project description. such as score criteria, project requirements, project limitations
# Predicted Sentence: The sentiment polarity of re quality is neutral. pol. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: I want this course to be more practical, it is mainly about the theory that the students cannot cause to learn more about [course], even though it is fun in real life and is useful. I wish that itshould concentrate more on
# Predicted Sentence: The sentiment polarity of re is neutral. pol. pol pol pol pol.. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: He didn’t clear to assign homework, and he never adapt himself. i commented he in [subject] in the same problem.
# Predicted Sentence: The sentiment polarity of organization usability is neutral. pol pol pol pol pol polarity pol pol pol polad pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol polarity pol
#
# Input Sentence: Too much work and why you assign a project before the final.
# Predicted Sentence: The sentiment polarity of instructor is neutral. pol pol pol pol. pol pol. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol. pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: I also could not memorize the whole structure and find myself very difficult with the subject. However, one night, by my compassion and a liter of coffee, I decided to revise the [lessons] of the lastSemester from the
# Predicted Sentence: The sentiment polarity of re quality is neutral.arity.. pol. pol. pol pol pol pol pol pol pol pol pol pol pol pol.. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol
#
# Input Sentence: Great teacher, very caring and respectful.
# Predicted Sentence: The sentiment polarity of re usability is neutral. pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol pol

# %%
import os
print(os.getcwd())
# Out:
# /home/sinsin/ICTeval_code

# %%
# !ls ICTeval_code/crossvalid/set2/

# %%
# !du -sh * | sort -hr | head -n 20

# %%
# CUDA_LAUNCH_BLOCKING=1
